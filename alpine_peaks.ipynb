# %% [markdown]
# # Alpine Peaks from Openstreetmap
# ## How to combine a bunch of Shapefiles (or QGIS vector layers) into a single one without dublicates
# I've just downloaded a lot of points - all peaks of the Alps - from [Openstreetmap](https://www.openstreetmap.org) using the [QuickOSM](https://plugins.qgis.org/plugins/QuickOSM/) plugin in [QGIS](https://www.qgis.org) (search key: natural, value: peak). But to avoid connection timeouts, I had to narrow down my area of interest for each request. Now I want to combine the resulting QGIS layers (shapefiles) into one layer, without the duplicates. This would be tricky in QGIS, but Python comes to help.
#
# In the second section of this notebook, I explain [how to check if a feature is within a polygon (e.g. within a country)](#section2).
#
# Jupyter Notebook by [Florian Neukirchen](https://www.riannek.de/).
#
# Sorry, this notebooks comes without the data. It should be easy to adapt the code to be used with your own project.
#
# ![QGIS with 8 layers of peak data downloaded from openstreetmap](https://raw.githubusercontent.com/florianneukirchen/jupyter-notebooks/main/alpinepeaks.png)

# %%
import pandas as pd
import geopandas as gpd
import os

folder = 'alpinepeaks'

# %% [markdown]
# Create a list of all shapefiles

# %%
filelist = []
for file in os.listdir(folder):
    if file.endswith(('.shp')):
        filelist.append(file)

filelist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7506/1064562090.py in <cell line: 2>()
#       1 filelist = []
# ----> 2 for file in os.listdir(folder):
#       3     if file.endswith(('.shp')):
#       4         filelist.append(file)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'alpinepeaks'

# %% [markdown]
# Read all shapefiles into a single geopandas GeoDataFrame

# %%
gdf = gpd.read_file(os.path.join(folder, filelist[0]))
gdf.set_index('full_id', inplace=True)

for file in filelist[1:]:
    newgdf = gpd.read_file(os.path.join(folder, file))
    newgdf.set_index('full_id', inplace=True)
    gdf = pd.concat([gdf, newgdf], sort=True) # Sort columns

# %%
# remove duplicates
gdf = gdf[~gdf.index.duplicated(keep='first')]

# %%
gdf.head()
# Out:
#              osm_id osm_type natural note_de source_add source_not  peak  \
# full_id
# n26862532  26862532     node    peak    None       None       None  None
# n26862596  26862596     node    peak    None       None       None  None
# n26862749  26862749     node    peak    None       None       None  None
# n26862811  26862811     node    peak    None       None       None  None
# n26863052  26863052     node    peak    None       None       None  None
#
#           operator checkpoint checkpoi_1  ... ele_AT ele_nn_1 cross_star  \
# full_id                                   ...
# n26862532     None       None       None  ...    NaN      NaN        NaN
# n26862596     None       None       None  ...    NaN      NaN        NaN
# n26862749     None       None       None  ...    NaN      NaN        NaN
# n26862811     None       None       None  ...    NaN      NaN        NaN
# n26863052     None       None       None  ...    NaN      NaN        NaN
#
#           image_pano ele_müm name_de_DE name_de_AT cross_mate name_fa nat_name
# full_id
# n26862532        NaN     NaN        NaN        NaN        NaN     NaN      NaN
# n26862596        NaN     NaN        NaN        NaN        NaN     NaN      NaN
# n26862749        NaN     NaN        NaN        NaN        NaN     NaN      NaN
# n26862811        NaN     NaN        NaN        NaN        NaN     NaN      NaN
# n26863052        NaN     NaN        NaN        NaN        NaN     NaN      NaN
#
# [5 rows x 299 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 53440 entries, n26862532 to n10594918978
# Columns: 299 entries, osm_id to nat_name
# dtypes: geometry(1), object(298)
# memory usage: 124.3+ MB

# %% [markdown]
# ### Get rid of uninteresting data
# Chances are we have a lot of Nan values. First I remove rows without name (I don't need them)

# %%
gdf = gdf[gdf['name'].notna()]

# %% [markdown]
# We have a lot of useless columns (mostly NaN):

# %%
len(list(gdf.columns))
# Out:
# 299

# %%
sorted(list(gdf.columns))
# Out:
# ['KT HPO',
#  'PDOP_2',
#  'TOP_NOMAI',
#  'access',
#  'addr_city',
#  'addr_hamle',
#  'addr_place',
#  'addr_stree',
#  'aerialway',
#  'aerialway_',
#  'alias',
#  'alt_NHN',
#  'alt_WGS84',
#  'alt_loc_na',
#  'alt_müm',
#  'alt_name',
#  'alt_name2',
#  'alt_name_1',
#  'alt_name_2',
#  'alt_name_d',
#  'alt_name_e',
#  'alt_name_f',
#  'alt_name_h',
#  'alt_name_i',
#  'alt_name_l',
#  'alt_name_r',
#  'alt_name_s',
#  'alt_name_v',
#  'amenity',
#  'archaeolog',
#  'artist_nam',
#  'artwork_ty',
#  'backrest',
#  'bench',
#  'board_type',
#  'boundary',
#  'c2c_id',
#  'castle_t_1',
#  'castle_typ',
#  'check_date',
#  'checkpoi_1',
#  'checkpoint',
#  'climbing',
#  'climbing_g',
#  'climbing_s',
#  'colour',
#  'comment',
#  'communic_1',
#  'communicat',
#  'constructi',
#  'cross',
#  'cross_colo',
#  'cross_heig',
#  'cross_mate',
#  'cross_name',
#  'cross_star',
#  'denominati',
#  'descript_1',
#  'descript_2',
#  'descriptio',
#  'designatio',
#  'direction',
#  'dispute_wi',
#  'dsou',
#  'ele',
#  'ele_AT',
#  'ele_NN',
#  'ele_barome',
#  'ele_de',
#  'ele_ft',
#  'ele_müa',
#  'ele_müm',
#  'ele_nn_1',
#  'ele_source',
#  'ele_unknow',
#  'ele_wgs84',
#  'electrifie',
#  'elev',
#  'else',
#  'entrance',
#  'expected_l',
#  'expected_r',
#  'format',
#  'format_top',
#  'free_fly_1',
#  'free_fly_2',
#  'free_flyin',
#  'geometry',
#  'gps_pdop',
#  'guidepost',
#  'guy_wired',
#  'height',
#  'heritage',
#  'heritage_o',
#  'hiking',
#  'historic',
#  'image',
#  'image_pano',
#  'importance',
#  'informatio',
#  'inscript_1',
#  'inscriptio',
#  'internet_a',
#  'is_in',
#  'isolation',
#  'lat',
#  'latitude',
#  'layer',
#  'leisure',
#  'link',
#  'loc_name',
#  'loc_name_d',
#  'loc_name_f',
#  'loc_name_s',
#  'loc_ref',
#  'local_name',
#  'lon',
#  'longitude',
#  'lwn_name',
#  'man_made',
#  'map_type',
#  'mapillary',
#  'marker',
#  'massif',
#  'material',
#  'memorial',
#  'mountain_p',
#  'name',
#  'name_1',
#  'name_als',
#  'name_alt',
#  'name_ar',
#  'name_at',
#  'name_bar',
#  'name_be',
#  'name_bg',
#  'name_ch',
#  'name_cim',
#  'name_cs',
#  'name_de',
#  'name_de_1',
#  'name_de_AT',
#  'name_de_DE',
#  'name_en',
#  'name_eo',
#  'name_es',
#  'name_fa',
#  'name_fr',
#  'name_frp',
#  'name_fur',
#  'name_ga',
#  'name_gsw',
#  'name_he',
#  'name_hr',
#  'name_hu',
#  'name_it',
#  'name_ja',
#  'name_ko',
#  'name_lad',
#  'name_lij',
#  'name_lld',
#  'name_lmo',
#  'name_local',
#  'name_lt',
#  'name_mhn',
#  'name_mk',
#  'name_oc',
#  'name_old',
#  'name_pl',
#  'name_pms',
#  'name_pronu',
#  'name_rm',
#  'name_ro',
#  'name_ru',
#  'name_sk',
#  'name_sl',
#  'name_slo',
#  'name_sr',
#  'name_th',
#  'name_tt',
#  'name_uk',
#  'name_ur',
#  'name_vec',
#  'name_wae',
#  'name_zh',
#  'name_zh-Ha',
#  'nat_name',
#  'natural',
#  'natural_pr',
#  'nature',
#  'network',
#  'network_ty',
#  'noexit',
#  'noname',
#  'note_1',
#  'note_de',
#  'note_ele',
#  'note_en',
#  'note_fr',
#  'note_it',
#  'note_name',
#  'note_summi',
#  'odbl',
#  'official_1',
#  'official_n',
#  'old_fixme',
#  'old_name',
#  'old_name_1',
#  'old_name_2',
#  'old_name_d',
#  'old_name_i',
#  'old_name_s',
#  'old_source',
#  'operator',
#  'osm_id',
#  'osm_type',
#  'outdoor',
#  'pdop',
#  'peak',
#  'place',
#  'place_2',
#  'position',
#  'prominence',
#  'public_tra',
#  'ref',
#  'ref_FR_FAN',
#  'ref_ab',
#  'ref_at_bda',
#  'ref_at_tkk',
#  'ref_avf',
#  'ref_whc',
#  'reg_name',
#  'related_wi',
#  'religion',
#  'ruins',
#  'sac_scale',
#  'short_na_1',
#  'short_name',
#  'sota_summi',
#  'sou',
#  'source2',
#  'source_1',
#  'source_a_1',
#  'source_add',
#  'source_alt',
#  'source_coo',
#  'source_dat',
#  'source_e_1',
#  'source_ele',
#  'source_gps',
#  'source_lin',
#  'source_loc',
#  'source_n_1',
#  'source_nam',
#  'source_nat',
#  'source_not',
#  'source_off',
#  'source_old',
#  'source_pos',
#  'source_pro',
#  'source_ref',
#  'sources',
#  'sport',
#  'spu',
#  'start_da_1',
#  'start_date',
#  'subject__1',
#  'subject_wi',
#  'summit_bel',
#  'summit_c_1',
#  'summit_c_2',
#  'summit_c_3',
#  'summit_c_4',
#  'summit_c_5',
#  'summit_cai',
#  'summit_cro',
#  'summit_log',
#  'summit_reg',
#  'survey_dat',
#  'tourism',
#  'tourism_1',
#  'tower_type',
#  'upload',
#  'url',
#  'viewpoint',
#  'volcano_st',
#  'website',
#  'whc_inscri',
#  'wheelchair',
#  'wikidata',
#  'wikidata_2',
#  'wikimedia_',
#  'wikipedi_1',
#  'wikipedi_2',
#  'wikipedia',
#  'wikipedia_',
#  'wpt_descri',
#  'wpt_symbol',
#  'year']

# %% [markdown]
# To check for e.g. 'outdoor':

# %%
gdf[gdf['outdoor'].notna()].dropna(axis=1) # Only two rows
# Out:
#                  osm_id osm_type natural          name   ele  \
# full_id
# n2315712582  2315712582     node    peak  Gitschenwand  1527
# n3608997834  3608997834     node    peak  Wilhelmswand  1527
#
#                               geometry     sport outdoor climbing_s
# full_id
# n2315712582  POINT (13.25964 47.63427)  climbing     yes        yes
# n3608997834  POINT (13.23998 47.63271)  climbing     yes        yes

# %% [markdown]
# Only keep useful columns

# %%
useful = ['name', 'prominence', 'ele', 'geometry', 'name_en', 'name_fr', 'name_it', 'name_de', 'alias', 'alt_name', 'sport', 'name_1', 'name_de_AT',
 'name_de_DE', 'name_ch', 'name_sl']

# %%
gdf = gdf[useful]

# %% [markdown]
# Add lat and lon columns

# %%
gdf['lon'] = gdf.geometry.x
gdf['lat'] = gdf.geometry.y

# %% [markdown]
# ### Save
# I save the result as geojson

# %%
gdf.to_file(os.path.join(folder, "peaks.geojson"), driver='GeoJSON')

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## How to check if a feature is within a polygon (e.g. within a country)
# To my peak data I want to add the corresponding countries and mountain areas. A peak can be on a border and belong to more than one country, but it should only be within one mountain area. This means we need different approaches.
#
# ### Add countries
# For this, I downloaded the countries of the area with QuickOSM (key: admin_level, value: 2).

# %%
# Import if you haven't already
import pandas as pd
import geopandas as gpd
import os

folder = 'alpinepeaks'

# Optionally load again
gdf = gpd.read_file(os.path.join(folder, "peaks.geojson"))
gdf.set_index('full_id', inplace=True)

# %%
countries = gpd.read_file(os.path.join(folder, 'countries.gpkg'))

# %%
# Get rid of the double Monaco
countries.replace('Monaco (territorial waters)', 'Monaco', inplace=True)
countries = countries.dissolve(by='name:en')

# %% [markdown]
# The last line also sets 'name:en' as index. That means we only need index + geometry

# %%
countries = countries[[ 'geometry']]

# %% [markdown]
# Add a buffer of 50 m to countries (first reproject from WGS84 to UTM) to make sure that peaks on the border really get both countries.

# %%
countries = countries.to_crs("EPSG:32634")
countries.geometry = countries.geometry.buffer(50)
# Back to WGS84
countries = countries.to_crs("EPSG:4326")

# %% [markdown]
# I create one column per country with True or False.
#
# **The next cell is slow.**

# %%
for c in countries.index:
    print('processing', c)
    gdf[c] = gdf['geometry'].within(countries.loc[c].geometry)
# Out:
# processing Austria
# processing France
# processing Germany
# processing Italy
# processing Liechtenstein
# processing Monaco
# processing Slovenia
# processing Switzerland

# %%
gdf.head()
# Out:
#                   name prominence   ele name_en name_fr name_it alias  \
# full_id
# n26862532    Basališče        606  1272    None    None    None  None
# n26862596          Boč        657   978    None    None    None  None
# n26862749     Črni vrh        945  1543    None    None    None  None
# n26862811  Dürrenstein        809  1878    None    None    None  None
# n26863052       Göller        632  1766    None    None    None  None
#
#           alt_name sport name_1  ... name_de_DE                   geometry  \
# full_id                          ...
# n26862532     None  None   None  ...       None  POINT (15.24009 46.39020)
# n26862596     None  None   None  ...       None  POINT (15.59975 46.28959)
# n26862749     None  None   None  ...       None  POINT (15.23320 46.48562)
# n26862811     None  None   None  ...       None  POINT (15.05943 47.78573)
# n26863052     None  None   None  ...       None  POINT (15.49189 47.79369)
#
#           Austria  France  Germany  Italy  Liechtenstein  Monaco  Slovenia  \
# full_id
# n26862532   False   False    False  False          False   False      True
# n26862596   False   False    False  False          False   False      True
# n26862749   False   False    False  False          False   False      True
# n26862811    True   False    False  False          False   False     False
# n26863052    True   False    False  False          False   False     False
#
#            Switzerland
# full_id
# n26862532        False
# n26862596        False
# n26862749        False
# n26862811        False
# n26863052        False
#
# [5 rows x 21 columns]

# %% [markdown]
# Save again

# %%
gdf.to_file(os.path.join(folder, "peaks2.geojson"), driver='GeoJSON')

# %% [markdown]
# ### Add mountain area
# From openstreetmap I downloaded relations with region:type=mountain_area. I assume that a peak is only in one mountain area and I add only one column.

# %%
area = gpd.read_file(os.path.join(folder, 'mountain_region.gpkg'))

# %%
area.head()
# Out:
#     full_id   osm_id  osm_type name:th name:pnb name:li name:kk name:he  \
# 0  r2110285  2110285  relation    None     None    None    None    None
# 1  r2110286  2110286  relation    None     None    None    None    None
# 2  r2110287  2110287  relation    None     None    None    None    None
# 3  r2110288  2110288  relation    None     None    None    None    None
# 4  r2110289  2110289  relation    None     None    None    None    None
#
#   name:bh name:ast  ...                 name:fr             name:en  \
# 0    None     None  ...  Alpes de Berchtesgaden  Berchtesgaden Alps
# 1    None     None  ...                    None                None
# 2    None     None  ...                    None                None
# 3    None     None  ...               Hochkönig           Hochkönig
# 4    None     None  ...                    None                None
#
#                  name:de name:cs                   name boundary  \
# 0  Berchtesgadener Alpen    None  Berchtesgadener Alpen     None
# 1              Göllstock    None              Göllstock     None
# 2           Hagengebirge    None           Hagengebirge     None
# 3         Hochkönigstock    None         Hochkönigstock     None
# 4             Untersberg    None             Untersberg     None
#
#   TMC:cid_58:tabcd_1:LocationCode TMC:cid_58:tabcd_1:LCLversion  \
# 0                            6003                          9.00
# 1                            None                          None
# 2                            None                          None
# 3                            None                          None
# 4                            None                          None
#
#   TMC:cid_58:tabcd_1:Class                                           geometry
# 0                     Area  MULTIPOLYGON (((13.16332 47.59015, 13.16348 47...
# 1                     None  MULTIPOLYGON (((13.07942 47.71139, 13.07956 47...
# 2                     None  MULTIPOLYGON (((13.16822 47.58268, 13.16680 47...
# 3                     None  MULTIPOLYGON (((13.21158 47.44340, 13.21271 47...
# 4                     None  MULTIPOLYGON (((13.04564 47.71541, 13.04552 47...
#
# [5 rows x 116 columns]

# %% [markdown]
# I define a function so I don't need to loop over the data frame.

# %%
def mountain_area(point):
    for a in area.index:
        if point.within(area.loc[a].geometry):
            return area.loc[a]['name']
    return None

# %%
gdf['mountain_area'] = gdf['geometry'].map(mountain_area)

# %%
gdf.head()
# Out:
#                   name prominence   ele name_en name_fr name_it alias  \
# full_id
# n26862532    Basališče        606  1272    None    None    None  None
# n26862596          Boč        657   978    None    None    None  None
# n26862749     Črni vrh        945  1543    None    None    None  None
# n26862811  Dürrenstein        809  1878    None    None    None  None
# n26863052       Göller        632  1766    None    None    None  None
#
#           alt_name sport name_1  ...                   geometry Austria  \
# full_id                          ...
# n26862532     None  None   None  ...  POINT (15.24009 46.39020)   False
# n26862596     None  None   None  ...  POINT (15.59975 46.28959)   False
# n26862749     None  None   None  ...  POINT (15.23320 46.48562)   False
# n26862811     None  None   None  ...  POINT (15.05943 47.78573)    True
# n26863052     None  None   None  ...  POINT (15.49189 47.79369)    True
#
#           France  Germany  Italy  Liechtenstein  Monaco  Slovenia  \
# full_id
# n26862532  False    False  False          False   False      True
# n26862596  False    False  False          False   False      True
# n26862749  False    False  False          False   False      True
# n26862811  False    False  False          False   False     False
# n26863052  False    False  False          False   False     False
#
#            Switzerland                 mountain_area
# full_id
# n26862532        False                     Karavanke
# n26862596        False                          None
# n26862749        False  Karawanken und Bachergebirge
# n26862811        False               Ybbstaler Alpen
# n26863052        False              Mürzsteger Alpen
#
# [5 rows x 22 columns]

# %% [markdown]
# Save again

# %%
gdf.to_file(os.path.join(folder, "peaks2.geojson"), driver='GeoJSON')

# %% [markdown]
# ## Get rid of Multipoints and other problems
# These were crashing my QGIS workflow

# %%
# This ele cant be converted to float
gdf.at['n670140790', 'ele'] # '1843.41;1843.69'
# Out:
# '1843.41'

# %%
gdf.at['n670140790', 'ele'] = '1843.41'

# %%
from shapely.geometry import Point
gdf[gdf.geometry.geom_type != 'Point']
# Out:
#                                               name prominence   ele name_en  \
# full_id
# n26862538                       Becco di Filadonna       None  2150    None
# n26862539                      Col Becchei Dessora       None  2794    None
# n26862546                           Benediktenwand       None  1800    None
# n26862641                                Buchstein       None  1701    None
# n26862661     Kesselkogel - Catinaccio d'Antermoia       None  3004    None
# ...                                            ...        ...   ...     ...
# n10588808919                      Monte del Riposo       None  2109    None
# n10588859449                           Colle Sella       None  1059    None
# n10589170841                         Monte Fondoli       None  1534    None
# n10589263330                       Cornetto Bianco       None  2383    None
# n10589991857                        Monte Castelìr       None   440    None
#
#              name_fr                 name_it alias alt_name sport name_1  ...  \
# full_id                                                                   ...
# n26862538       None                    None  None     None  None   None  ...
# n26862539       None                    None  None     None  None   None  ...
# n26862546       None                    None  None     None  None   None  ...
# n26862641       None                    None  None     None  None   None  ...
# n26862661       None  Catinaccio d'Antermoia  None     None  None   None  ...
# ...              ...                     ...   ...      ...   ...    ...  ...
# n10588808919    None                    None  None     None  None   None  ...
# n10588859449    None                    None  None     None  None   None  ...
# n10589170841    None                    None  None     None  None   None  ...
# n10589263330    None                    None  None     None  None   None  ...
# n10589991857    None                    None  None     None  None   None  ...
#
#                                     geometry Austria France  Germany  Italy  \
# full_id
# n26862538     MULTIPOINT (11.19347 45.96363)   False  False    False   True
# n26862539     MULTIPOINT (12.04457 46.60775)   False  False    False   True
# n26862546     MULTIPOINT (11.46554 47.65317)   False  False     True  False
# n26862641     MULTIPOINT (11.67937 47.63307)   False  False     True  False
# n26862661     MULTIPOINT (11.64383 46.47409)   False  False    False   True
# ...                                      ...     ...    ...      ...    ...
# n10588808919  MULTIPOINT (11.43760 46.61288)   False  False    False   True
# n10588859449  MULTIPOINT (11.35257 46.53738)   False  False    False   True
# n10589170841  MULTIPOINT (11.53246 46.65265)   False  False    False   True
# n10589263330  MULTIPOINT (11.46531 46.69760)   False  False    False   True
# n10589991857  MULTIPOINT (11.92826 45.94251)   False  False    False   True
#
#               Liechtenstein  Monaco  Slovenia  Switzerland  \
# full_id
# n26862538             False   False     False        False
# n26862539             False   False     False        False
# n26862546             False   False     False        False
# n26862641             False   False     False        False
# n26862661             False   False     False        False
# ...                     ...     ...       ...          ...
# n10588808919          False   False     False        False
# n10588859449          False   False     False        False
# n10589170841          False   False     False        False
# n10589263330          False   False     False        False
# n10589991857          False   False     False        False
#
#                          mountain_area
# full_id
# n26862538            Prealpi Vicentine
# n26862539                     Dolomiti
# n26862546          Bayerische Voralpen
# n26862641          Bayerische Voralpen
# n26862661                     Dolomiti
# ...                                ...
# n10588808919           Sarntaler Alpen
# n10588859449           Sarntaler Alpen
# n10589170841           Sarntaler Alpen
# n10589263330           Sarntaler Alpen
# n10589991857  Südliche Karnische Alpen
#
# [6927 rows x 22 columns]

# %%
gdf = gdf.explode(index_parts=False)

# %%
gdf[gdf.geometry.geom_type != 'Point']
# Out:
# Empty GeoDataFrame
# Columns: [name, prominence, ele, name_en, name_fr, name_it, alias, alt_name, sport, name_1, name_de_AT, name_de_DE, Austria, France, Germany, Italy, Liechtenstein, Monaco, Slovenia, Switzerland, mountain_area, geometry]
# Index: []
#
# [0 rows x 22 columns]

# %%
gdf.to_file(os.path.join(folder, "peaks2.geojson"), driver='GeoJSON')
